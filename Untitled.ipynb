# %%
# !conda create -n yolov10 python=3.9 -y
# !conda activate yolov10
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/tanvir-rahman/anaconda3/envs/yolov10
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.12.31 |       h06a4308_0         128 KB
#     pip-25.0                   |   py39h06a4308_0         2.3 MB
#     python-3.9.21              |       he870216_1        25.1 MB
#     setuptools-75.8.0          |   py39h06a4308_0         1.6 MB
#     tzdata-2025a               |       h04d1e81_0         117 KB
#     wheel-0.45.1               |   py39h06a4308_0         114 KB
#     ------------------------------------------------------------
#                                            Total:        29.3 MB
#
# The following NEW packages will be INSTALLED:
#
# ...
